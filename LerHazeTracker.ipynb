# %%
pip install requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [requests]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
r = requests.get("https://api-open.data.gov.sg/v2/real-time/api/psi")
data = r.json()
print(data)
# Out:
# {'code': 0, 'data': {'regionMetadata': [{'name': 'south', 'labelLocation': {'latitude': 1.29587, 'longitude': 103.82}}, {'name': 'central', 'labelLocation': {'longitude': 103.82, 'latitude': 1.35735}}, {'name': 'east', 'labelLocation': {'latitude': 1.35735, 'longitude': 103.94}}, {'name': 'north', 'labelLocation': {'longitude': 103.82, 'latitude': 1.41803}}, {'name': 'west', 'labelLocation': {'latitude': 1.35735, 'longitude': 103.7}}], 'items': [{'date': '2026-09-16', 'updatedTimestamp': '2026-09-16T12:30:45+08:00', 'timestamp': '2026-09-16T12:00:00+08:00', 'readings': {'psi_twenty_four_hourly': {'east': 83, 'central': 98, 'north': 76, 'south': 74, 'west': 84}, 'co_eight_hour_max': {'north': 1, 'west': 1, 'south': 0, 'central': 0, 'east': 0}, 'o3_sub_index': {'south': 10, 'east': 15, 'north': 16, 'central': 15, 'west': 8}, 'so2_twenty_four_hourly': {'west': 14, 'east': 4, 'central': 6, 'south': 2, 'north': 6}, 'pm25_sub_index': {'north': 76, 'west': 84, 'central': 98, 'south': 74, 'e
# ...
